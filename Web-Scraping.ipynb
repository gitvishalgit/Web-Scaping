# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
Product_name = []
Price = []
Description = []
Reviews = []
for page_no in range(2,12): # iterating from one page to next page
    url = "https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(page_no)
    r = requests.get(url) # get method 
    soup = BeautifulSoup(r.text,"lxml")
    box = soup.find('div', class_ = "_1YokD2 _3Mn1Gg")


    names = box.find_all("div",class_ = '_4rR01T')
    for i in names:
        name = i.text
        Product_name.append(name)
    print(len(Product_name))

    prices = box.find_all('div',class_ = "_30jeq3 _1_WHN1") # _30jeq3 _1_WHN1
    for i in prices:
        name = i.text
        Price.append(name)
    print(len(Price))

    desc = box.find_all('ul',class_='_1xgFaf')
    for i in desc:
        name = i.text
        Description.append(name)
    print(len(Description))

    rev = box.find_all('div',class_ = '_3LWZlK')
    for i in rev:
        name = i.text
        Reviews.append(name)
    print(len(Reviews))

df = pd.DataFrame({"Product Name":Product_name,"Prices":Price,"Description":Description,"Reviews":Reviews})
df.to_csv('flipcart_mobile_data.csv')

# %%
df = pd.read_csv("flipcart_mobile_data.csv")
df
# Out:
#      Unnamed: 0                              Product Name   Prices  \
# 0             0       realme X50 Pro (Moss Green, 256 GB)  ₹47,999
# 1             1       OnePlus 10T 5G (Jade Green, 128 GB)  ₹45,999
# 2             2         Apple iPhone 8 Plus (Gold, 64 GB)  ₹49,900
# 3             3  SAMSUNG Galaxy S7 (Gold Platinum, 32 GB)  ₹46,000
# 4             4   Apple iPhone 8 Plus (Space Grey, 64 GB)  ₹49,900
# ..          ...                                       ...      ...
# 235         235    Infinix HOT 30i (Glacier Blue, 128 GB)   ₹8,299
# 236         236           POCO X6 Pro 5G (Yellow, 256 GB)  ₹26,999
# 237         237        Infinix HOT 30i (Marigold, 128 GB)   ₹8,299
# 238         238          vivo T2 5G (Nitro Blaze, 128 GB)  ₹17,999
# 239         239     Infinix HOT 30i (Glacier Blue, 64 GB)   ₹8,399
#
#                                            Description  Reviews
# 0    12 GB RAM | 256 GB ROM16.36 cm (6.44 inch) Ful...      4.4
# ...
